# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:*Sabriny Kauany de Miranda Mendes Veloso*
#
# **Turma:*2º B T.I.*
#
# **Tema Escolhido:*Crie um sistema que registre o humor diário dos alunos, cadastrando  data, humor (feliz, triste, neutro) e comentários, gerando gráficos semanais.  *

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class HumorAluno_Sabriny:
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny):
        self.data_Sabriny = data_Sabriny
        self.humor_Sabriny = humor_Sabriny
        self.comentario_Sabriny = comentario_Sabriny

    def exibir_dados_Sabriny(self, indice=None):
        if indice is not None:
            print(f"Registro #{indice}")
        print(f"Data: {self.data_Sabriny} | Humor: {self.humor_Sabriny} | Comentário: {self.comentario_Sabriny}\n")


def menu_Sabriny():
    registros = []

    while True:
        print("1. Cadastrar humor")
        print("2. Exibir registros")
        print("3. Excluir registro")
        print("4. Sair")
        escolha = input("Opção: ")

        if escolha == '1':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            registros.append(HumorAluno_Sabriny(data, humor, comentario))
            print("Registro cadastrado!\n")

        elif escolha == '2':
            if not registros:
                print("Nenhum registro.\n")
            else:
                for i, reg in enumerate(registros, 1):
                    reg.exibir_dados_Sabriny(i)

        elif escolha == '3':
            if not registros:
                print("Nenhum registro para excluir.\n")
                continue
            for i, reg in enumerate(registros, 1):
                print(f"{i}. {reg.data_Sabriny} - {reg.humor_Sabriny}")
            try:
                num = int(input("Número do registro para excluir: "))
                if 1 <= num <= len(registros):
                    confirm = input("Confirma exclusão? (s/n): ").lower()
                    if confirm == 's':
                        registros.pop(num - 1)
                        print("Registro excluído.\n")
                    else:
                        print("Exclusão cancelada.\n")
                else:
                    print("Número inválido.\n")
            except ValueError:
                print("Entrada inválida.\n")

        elif escolha == '4':
            print("Saindo...")
            break

        else:
            print("Opção inválida.\n")


menu_Sabriny()
# Out:
# 1. Cadastrar humor
# 2. Exibir registros
# 3. Excluir registro
# 4. Sair
# Opção:  5
# Opção inválida.
#
# 1. Cadastrar humor
# 2. Exibir registros
# 3. Excluir registro
# 4. Sair
# Opção:  4
# Saindo...

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class HumorAluno_Sabriny:
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny):
        self.data_Sabriny = data_Sabriny
        self.humor_Sabriny = humor_Sabriny
        self.comentario_Sabriny = comentario_Sabriny

    def exibir_dados_Sabriny(self, indice=None):
        if indice:
            print(f"Registro #{indice}")
        print(f"Data: {self.data_Sabriny} | Humor: {self.humor_Sabriny} | Comentário: {self.comentario_Sabriny}\n")

    def alterar_humor_Sabriny(self, novo_humor):
        self.humor_Sabriny = novo_humor
        print("Humor alterado com sucesso!")

    def atualizar_comentario_Sabriny(self, novo_comentario):
        self.comentario_Sabriny = novo_comentario
        print("Comentário atualizado com sucesso!")


class HumorAlunoDetalhado_Sabriny(HumorAluno_Sabriny):
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny, nota_dia_Sabriny):
        super().__init__(data_Sabriny, humor_Sabriny, comentario_Sabriny)
        self.nota_dia_Sabriny = nota_dia_Sabriny  # novo atributo exclusivo

    def exibir_dados_completos_Sabriny(self, indice=None):
        if indice:
            print(f"Registro Detalhado #{indice}")
        self.exibir_dados_Sabriny()
        print(f"Nota do dia (0 a 10): {self.nota_dia_Sabriny}\n")

    def avaliar_dia_Sabriny(self):
        if self.nota_dia_Sabriny >= 7:
            print("Avaliação: Dia excelente!")
        elif self.nota_dia_Sabriny >= 4:
            print("Avaliação: Dia mediano.")
        else:
            print("Avaliação: Dia difícil.")


def menu_Sabriny():
    registros = []

    while True:
        print("1. Cadastrar humor básico")
        print("2. Cadastrar humor detalhado")
        print("3. Exibir registros")
        print("4. Alterar registro")
        print("5. Sair")
        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            registros.append(HumorAluno_Sabriny(data, humor, comentario))
            print("Registro básico cadastrado!\n")

        elif escolha == '2':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            try:
                nota = float(input("Nota do dia (0 a 10): "))
                if nota < 0 or nota > 10:
                    print("Nota inválida. Deve ser entre 0 e 10.\n")
                    continue
            except ValueError:
                print("Entrada inválida para nota.\n")
                continue

            registros.append(HumorAlunoDetalhado_Sabriny(data, humor, comentario, nota))
            print("Registro detalhado cadastrado!\n")

        elif escolha == '3':
            if not registros:
                print("Nenhum registro cadastrado.\n")
            else:
                for i, reg in enumerate(registros, 1):
                    if isinstance(reg, HumorAlunoDetalhado_Sabriny):
                        reg.exibir_dados_completos_Sabriny(i)
                        reg.avaliar_dia_Sabriny()
                    else:
                        reg.exibir_dados_Sabriny(i)

        elif escolha == '4':
            if not registros:
                print("Nenhum registro para alterar.\n")
                continue

            for i, reg in enumerate(registros, 1):
                tipo = "Detalhado" if isinstance(reg, HumorAlunoDetalhado_Sabriny) else "Básico"
                print(f"{i}. {reg.data_Sabriny} - {reg.humor_Sabriny} ({tipo})")

            try:
                num = int(input("Número do registro para alterar: "))
                if num < 1 or num > len(registros):
                    print("Número inválido.\n")
                    continue
            except ValueError:
                print("Entrada inválida.\n")
                continue

            reg = registros[num - 1]

            novo_humor = input("Novo humor (deixe vazio para não alterar): ").lower()
            if novo_humor:
                reg.alterar_humor_Sabriny(novo_humor)

            novo_comentario = input("Novo comentário (deixe vazio para não alterar): ")
            if novo_comentario:
                reg.atualizar_comentario_Sabriny(novo_comentario)

            if isinstance(reg, HumorAlunoDetalhado_Sabriny):
                try:
                    nova_nota = input("Nova nota do dia (0 a 10, vazio para não alterar): ")
                    if nova_nota:
                        nova_nota = float(nova_nota)
                        if 0 <= nova_nota <= 10:
                            reg.nota_dia_Sabriny = nova_nota
                            print("Nota atualizada com sucesso!")
                        else:
                            print("Nota inválida. Ignorando alteração.")
                except ValueError:
                    print("Entrada inválida para nota. Ignorando alteração.")

            print()

        elif escolha == '5':
            print("Saindo do sistema. Até mais!")
            break

        else:
            print("Opção inválida.\n")


menu_Sabriny()
# Out:
# 1. Cadastrar humor básico
# 2. Cadastrar humor detalhado
# 3. Exibir registros
# 4. Alterar registro
# 5. Sair
# Escolha uma opção:  5
# Saindo do sistema. Até mais!

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class HumorAluno_Sabriny:
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny):
        self.data_Sabriny = data_Sabriny
        self.humor_Sabriny = humor_Sabriny
        self.__comentario_Sabriny = comentario_Sabriny  # atributo privado

    # Getter para comentário
    def get_comentario_Sabriny(self):
        return self.__comentario_Sabriny

    # Setter para comentário
    def set_comentario_Sabriny(self, novo_comentario):
        if isinstance(novo_comentario, str) and len(novo_comentario) <= 200:
            self.__comentario_Sabriny = novo_comentario
            print("Comentário atualizado com sucesso!")
        else:
            print("Comentário inválido ou muito longo (máx 200 caracteres).")

    def exibir_dados_Sabriny(self, indice=None):
        if indice:
            print(f"Registro #{indice}")
        print(f"Data: {self.data_Sabriny} | Humor: {self.humor_Sabriny} | Comentário: {self.__comentario_Sabriny}\n")

    # Método com lógica: verifica se humor é positivo
    def humor_positivo_Sabriny(self):
        return self.humor_Sabriny.lower() == 'feliz'


def menu_Sabriny():
    registros = []

    while True:
        print("1. Cadastrar humor")
        print("2. Exibir registros")
        print("3. Atualizar comentário")
        print("4. Verificar se humor é positivo")
        print("5. Sair")
        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            registros.append(HumorAluno_Sabriny(data, humor, comentario))
            print("Registro cadastrado!\n")

        elif escolha == '2':
            if not registros:
                print("Nenhum registro cadastrado.\n")
            else:
                for i, reg in enumerate(registros, 1):
                    reg.exibir_dados_Sabriny(i)

        elif escolha == '3':
            if not registros:
                print("Nenhum registro para atualizar.\n")
                continue

            for i, reg in enumerate(registros, 1):
                print(f"{i}. Data: {reg.data_Sabriny} - Humor: {reg.humor_Sabriny}")

            try:
                num = int(input("Número do registro para atualizar comentário: "))
                if 1 <= num <= len(registros):
                    novo_com = input("Digite o novo comentário (máx 200 caracteres): ")
                    registros[num-1].set_comentario_Sabriny(novo_com)
                else:
                    print("Número inválido.\n")
            except ValueError:
                print("Entrada inválida.\n")

        elif escolha == '4':
            if not registros:
                print("Nenhum registro para verificar.\n")
                continue

            for i, reg in enumerate(registros, 1):
                positivo = reg.humor_positivo_Sabriny()
                status = "positivo" if positivo else "não positivo"
                print(f"Registro #{i} em {reg.data_Sabriny}: Humor é {status}.")

            print()

        elif escolha == '5':
            print("Saindo do sistema. Até mais!")
            break

        else:
            print("Opção inválida.\n")


menu_Sabriny()
# Out:
# 1. Cadastrar humor
# 2. Exibir registros
# 3. Atualizar comentário
# 4. Verificar se humor é positivo
# 5. Sair
# Escolha uma opção:  5
# Saindo do sistema. Até mais!

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

#Classe principal
class HumorAluno_Sabriny:
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny):
        self.data_Sabriny = data_Sabriny
        self.humor_Sabriny = humor_Sabriny
        self.comentario_Sabriny = comentario_Sabriny

    def exibir_dados_Sabriny(self):
        print(f"Data: {self.data_Sabriny} | Humor: {self.humor_Sabriny} | Comentário: {self.comentario_Sabriny}")

    def salvar_no_bd_Sabriny(self, cursor):
        cursor.execute(
            "INSERT INTO humor (data, humor, comentario, tipo) VALUES (?, ?, ?, ?)",
            (self.data_Sabriny, self.humor_Sabriny, self.comentario_Sabriny, "basico")
        )


# Subclasse com polimorfismo
class HumorAlunoDetalhado_Sabriny(HumorAluno_Sabriny):
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny, nota_dia_Sabriny):
        super().__init__(data_Sabriny, humor_Sabriny, comentario_Sabriny)
        self.nota_dia_Sabriny = nota_dia_Sabriny

    # Sobrescreve método para exibir dados completos
    def exibir_dados_Sabriny(self):
        super().exibir_dados_Sabriny()
        print(f"Nota do dia: {self.nota_dia_Sabriny}")

    def salvar_no_bd_Sabriny(self, cursor):
        cursor.execute(
            "INSERT INTO humor (data, humor, comentario, tipo, nota) VALUES (?, ?, ?, ?, ?)",
            (self.data_Sabriny, self.humor_Sabriny, self.comentario_Sabriny, "detalhado", self.nota_dia_Sabriny)
        )


# Função para criar tabela SQLite (se não existir)
def criar_tabela_Sabriny(con):
    cursor = con.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS humor (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            data TEXT NOT NULL,
            humor TEXT NOT NULL,
            comentario TEXT,
            tipo TEXT NOT NULL,
            nota REAL
        )
    ''')
    con.commit()


def menu_Sabriny():
    con = sqlite3.connect('humor_alunos_sabriny.db')
    criar_tabela_Sabriny(con)
    cursor = con.cursor()

    while True:
        print("\n1. Cadastrar humor básico")
        print("2. Cadastrar humor detalhado")
        print("3. Exibir registros")
        print("4. Excluir registro")
        print("5. Sair")
        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            reg = HumorAluno_Sabriny(data, humor, comentario)
            reg.salvar_no_bd_Sabriny(cursor)
            con.commit()
            print("Registro básico salvo no banco.\n")

        elif escolha == '2':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            try:
                nota = float(input("Nota do dia (0 a 10): "))
                if nota < 0 or nota > 10:
                    print("Nota inválida. Deve ser entre 0 e 10.\n")
                    continue
            except ValueError:
                print("Entrada inválida para nota.\n")
                continue
            reg = HumorAlunoDetalhado_Sabriny(data, humor, comentario, nota)
            reg.salvar_no_bd_Sabriny(cursor)
            con.commit()
            print("Registro detalhado salvo no banco.\n")

        elif escolha == '3':
            cursor.execute("SELECT id, data, humor, comentario, tipo, nota FROM humor")
            rows = cursor.fetchall()
            if not rows:
                print("Nenhum registro encontrado.\n")
            else:
                for row in rows:
                    id_, data, humor, comentario, tipo, nota = row
                    print(f"ID: {id_} | Data: {data} | Humor: {humor} | Comentário: {comentario} | Tipo: {tipo}", end="")
                    if tipo == "detalhado":
                        print(f" | Nota: {nota}")
                    else:
                        print()

        elif escolha == '4':
            try:
                id_del = int(input("ID do registro para excluir: "))
                cursor.execute("DELETE FROM humor WHERE id = ?", (id_del,))
                if cursor.rowcount > 0:
                    con.commit()
                    print("Registro excluído.\n")
                else:
                    print("ID não encontrado.\n")
            except ValueError:
                print("Entrada inválida.\n")

        elif escolha == '5':
            print("Saindo do sistema...")
            break

        else:
            print("Opção inválida.\n")

    con.close()

menu_Sabriny()
# Out:
# 1. Cadastrar humor básico
# 2. Cadastrar humor detalhado
# 3. Exibir registros
# 4. Excluir registro
# 5. Sair
# Escolha uma opção:  5
# Saindo do sistema...

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector

# === CLASSE PRINCIPAL - HumorAluno_Sabriny ===
class HumorAluno_Sabriny:
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny):
        self.data_Sabriny = data_Sabriny
        self.humor_Sabriny = humor_Sabriny
        self.__comentario_Sabriny = comentario_Sabriny

    def get_comentario_Sabriny(self):
        return self.__comentario_Sabriny

    def set_comentario_Sabriny(self, novo_comentario):
        if isinstance(novo_comentario, str) and len(novo_comentario) <= 200:
            self.__comentario_Sabriny = novo_comentario
            print("Comentário atualizado com sucesso!")
        else:
            print("Comentário inválido ou muito longo (máx 200 caracteres).")

    def exibir_dados_Sabriny(self):
        print(f"Data: {self.data_Sabriny} | Humor: {self.humor_Sabriny} | Comentário: {self.__comentario_Sabriny}")

    def humor_positivo_Sabriny(self):
        return self.humor_Sabriny.lower() == 'feliz'

    def salvar_no_bd_Sabriny(self, cursor):
        sql = "INSERT INTO humor (data, humor, comentario, tipo) VALUES (%s, %s, %s, %s)"
        valores = (self.data_Sabriny, self.humor_Sabriny, self.__comentario_Sabriny, "basico")
        cursor.execute(sql, valores)


# === SUBCLASSE - HumorAlunoDetalhado_Sabriny ===
class HumorAlunoDetalhado_Sabriny(HumorAluno_Sabriny):
    def __init__(self, data_Sabriny, humor_Sabriny, comentario_Sabriny, nota_dia_Sabriny):
        super().__init__(data_Sabriny, humor_Sabriny, comentario_Sabriny)
        self.nota_dia_Sabriny = nota_dia_Sabriny

    def exibir_dados_Sabriny(self):
        super().exibir_dados_Sabriny()
        print(f"Nota do dia: {self.nota_dia_Sabriny}")

    def salvar_no_bd_Sabriny(self, cursor):
        sql = "INSERT INTO humor (data, humor, comentario, tipo, nota) VALUES (%s, %s, %s, %s, %s)"
        valores = (self.data_Sabriny, self.humor_Sabriny, self.get_comentario_Sabriny(), "detalhado", self.nota_dia_Sabriny)
        cursor.execute(sql, valores)


# === FUNÇÃO PRINCIPAL COM MENU INTERATIVO ===
def menu_Sabriny():
    try:

        
        con = mysql.connector.connect(
            host="localhost",
            user="root",
            password="",
            database="humor_alunos_sabriny"
        )
        cursor = con.cursor()




    
    except mysql.connector.Error as err:
        print(f"Erro ao conectar ao banco de dados: {err}")
        return

    while True:
        print("\n===== Sistema de Registro de Humor Diário - Sabriny =====")
        print("1. Cadastrar humor básico")
        print("2. Cadastrar humor detalhado")
        print("3. Exibir todos os registros")
        print("4. Atualizar comentário de um registro")
        print("5. Excluir registro")
        print("6. Verificar quais humores são positivos")
        print("7. Sair")
        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            reg = HumorAluno_Sabriny(data, humor, comentario)
            reg.salvar_no_bd_Sabriny(cursor)
            con.commit()
            print("Registro básico salvo com sucesso!\n")

        elif escolha == '2':
            data = input("Data (AAAA-MM-DD): ")
            humor = input("Humor (feliz, triste, neutro): ").lower()
            comentario = input("Comentário: ")
            try:
                nota = float(input("Nota do dia (0 a 10): "))
                if not (0 <= nota <= 10):
                    print("Nota inválida, deve ser entre 0 e 10.\n")
                    continue
            except ValueError:
                print("Entrada inválida para nota.\n")
                continue
            reg = HumorAlunoDetalhado_Sabriny(data, humor, comentario, nota)
            reg.salvar_no_bd_Sabriny(cursor)
            con.commit()
            print("Registro detalhado salvo com sucesso!\n")

        elif escolha == '3':
            cursor.execute("SELECT id, data, humor, comentario, tipo, nota FROM humor")
            rows = cursor.fetchall()
            if not rows:
                print("Nenhum registro encontrado.\n")
            else:
                for row in rows:
                    id_, data, humor, comentario, tipo, nota = row
                    print(f"ID: {id_} | Data: {data} | Humor: {humor} | Comentário: {comentario} | Tipo: {tipo}", end="")
                    if tipo == "detalhado":
                        print(f" | Nota: {nota}")
                    else:
                        print()

        elif escolha == '4':
            try:
                id_upd = int(input("Digite o ID do registro para atualizar comentário: "))
                novo_com = input("Digite o novo comentário (máx 200 caracteres): ")
                if len(novo_com) > 200:
                    print("Comentário muito longo.\n")
                    continue
                cursor.execute("UPDATE humor SET comentario = %s WHERE id = %s", (novo_com, id_upd))
                if cursor.rowcount == 0:
                    print("ID não encontrado.\n")
                else:
                    con.commit()
                    print("Comentário atualizado com sucesso!\n")
            except ValueError:
                print("Entrada inválida.\n")

        elif escolha == '5':
            try:
                id_del = int(input("Digite o ID do registro para excluir: "))
                cursor.execute("DELETE FROM humor WHERE id = %s", (id_del,))
                if cursor.rowcount == 0:
                    print("ID não encontrado.\n")
                else:
                    con.commit()
                    print("Registro excluído com sucesso!\n")
            except ValueError:
                print("Entrada inválida.\n")

        elif escolha == '6':
            cursor.execute("SELECT id, data, humor FROM humor")
            rows = cursor.fetchall()
            if not rows:
                print("Nenhum registro para verificar.\n")
            else:
                print("Registros com humor positivo (feliz):")
                for id_, data, humor in rows:
                    if humor.lower() == 'feliz':
                        print(f"ID: {id_} | Data: {data} | Humor: {humor}")
                print()

        elif escolha == '7':
            print("Saindo do sistema. Até mais!")
            break

        else:
            print("Opção inválida. Tente novamente.\n")

    cursor.close()
    con.close()


# === EXECUTA O MENU PRINCIPAL ===
if __name__ == "__main__":
    menu_Sabriny()
# Out:
# ===== Sistema de Registro de Humor Diário - Sabriny =====
# 1. Cadastrar humor básico
# 2. Cadastrar humor detalhado
# 3. Exibir todos os registros
# 4. Atualizar comentário de um registro
# 5. Excluir registro
# 6. Verificar quais humores são positivos
# 7. Sair
# Escolha uma opção:  1
# Data (AAAA-MM-DD):  2003/03/17
# Humor (feliz, triste, neutro):  triste
# Comentário:  oal
# Registro básico salvo com sucesso!
#
#
# ===== Sistema de Registro de Humor Diário - Sabriny =====
# 1. Cadastrar humor básico
# 2. Cadastrar humor detalhado
# 3. Exibir todos os registros
# 4. Atualizar comentário de um registro
# 5. Excluir registro
# 6. Verificar quais humores são positivos
# 7. Sair
